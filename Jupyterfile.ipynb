# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kavya\Downloads\archive (1)\netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.fillna({'director': 'NA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.fillna({'cast': 'NA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                    NA  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.fillna({'country': 'NA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                    NA  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.fillna({'date_added': 'NA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                    NA  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.fillna({'duration': 'NA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                    NA  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['rating'].mode()
# Out:
# 0    TV-MA
# Name: rating, dtype: str

# %%
df.fillna({'rating': 'TV-MA'},inplace = True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water               NA
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans               NA
# 4         s5  TV Show           Kota Factory               NA
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb               NA
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                    NA  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dropna(subset=['date_added', 'duration'], inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
a = df.groupby('type')['show_id'].count().reset_index()
a
# Out:
#       type  show_id
# 0    Movie     6131
# 1  TV Show     2676

# %% [markdown]
# movies vs tv shows

# %%
b = df.groupby('country')['show_id'].count().sort_values(ascending = False).head(10).reset_index()
b
# Out:
#           country  show_id
# 0   United States     2818
# 1           India      972
# 2              NA      831
# 3  United Kingdom      419
# 4           Japan      245
# 5     South Korea      199
# 6          Canada      181
# 7           Spain      145
# 8          France      124
# 9          Mexico      110

# %% [markdown]
# top 10 countries by no of titles

# %%
c = df.groupby('rating')['show_id'].count().reset_index()
c
# Out:
#       rating  show_id
# 0     66 min        1
# 1     74 min        1
# 2     84 min        1
# 3          G       41
# 4      NC-17        3
# 5         NR       80
# 6         PG      287
# 7      PG-13      490
# 8          R      799
# 9      TV-14     2160
# 10      TV-G      220
# 11     TV-MA     3211
# 12     TV-PG      863
# 13      TV-Y      307
# 14     TV-Y7      334
# 15  TV-Y7-FV        6
# 16        UR        3

# %% [markdown]
# common content ratings

# %%
print(df['rating'].unique())
# Out:
# <StringArray>
# [   'PG-13',    'TV-MA',       'PG',    'TV-14',    'TV-PG',     'TV-Y',
#     'TV-Y7',        'R',     'TV-G',        'G',    'NC-17',   '74 min',
#    '84 min',   '66 min',       'NR', 'TV-Y7-FV',       'UR']
# Length: 17, dtype: str

# %%
df = df[~df['rating'].str.contains('min', na=False)]

# %%
df.groupby('rating')['show_id'].count().reset_index()
# Out:
#       rating  show_id
# 0          G       41
# 1      NC-17        3
# 2         NR       80
# 3         PG      287
# 4      PG-13      490
# 5          R      799
# 6      TV-14     2160
# 7       TV-G      220
# 8      TV-MA     3211
# 9      TV-PG      863
# 10      TV-Y      307
# 11     TV-Y7      334
# 12  TV-Y7-FV        6
# 13        UR        3

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
country_count = df['country'].value_counts().head(10).reset_index()
country_count.columns = ['country', 'count']

# %%
sns.barplot(x='count', y='country', data=country_count, orient='h',hue = 'country')
plt.show()

# %% [markdown]
# top ten countries  count

# %%
type_count = df['type'].value_counts().reset_index()

# %%
type_count.columns = ['type', 'count']

# %%
sns.barplot(x='type', y='count', data=type_count,hue = 'type')
plt.show()

# %% [markdown]
# movies vs tv shows

# %%
year_count = df.groupby('release_year')['show_id'].count().reset_index()

# %%
plt.plot(year_count['release_year'],
         year_count['show_id']
    )
plt.show()

# %% [markdown]
# content added to netflix by year

# %%
country_type = df.groupby(['country', 'type'])['show_id'].count().reset_index()

country_type.head()
# Out:
#                                              country     type  show_id
# 0                                  , France, Algeria    Movie        1
# 1                                      , South Korea  TV Show        1
# 2                                          Argentina    Movie       38
# 3                                          Argentina  TV Show       18
# 4  Argentina, Brazil, France, Poland, Germany, De...    Movie        1

# %%
df['rating'].value_counts().plot(kind='barh', color = 'pink')
plt.xlabel('Count')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# RATING DISTRIBUTION
